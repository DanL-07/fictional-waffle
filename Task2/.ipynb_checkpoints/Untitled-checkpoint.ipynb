# %% [markdown]
# $$\sum_{K=0}^{\infty} \frac{1}{4k^2-1}=\frac{1}{2}$$
# $$\int\limits_0^\pi {e}^{-ix}\,\mathrm{d}x=2i$$

# %%
#Calculate angle in cartesian
x=float(input("Value for x:", ))
y=float(input("Value for y:", ))
import math
print ("The angle is: ", math.atan2(y,x)*57.2957795)
       
#Findout quadrant
if x>0 : 
    if y>0 : print("1st qd")
    else : print ("4th qd")
else: 
    if y>0 : print("2nd qd")
    else : print ("3rd qd")
# Out:
# Value for x: -1
# Value for y: 2
# The angle is:  116.56505115046275
# 2nd qd

# %%
X=[1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]
X.append (0.51)
X.remove (2.12)
x_slice = slice (2,7,2)
print (X[x_slice])
# Out:
# [1.41, 0.98, 1.97]

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

set1=set(night1)
set2=set(night2)
intersection=set1.intersection(set2)
print(intersection)
n=5 in set1
print(n)
# Out:
# {0, 1, 2, 3, 4}
# True

# %%
import numpy
d=numpy.random.normal(loc=0.0, scale=1.4, size=10000)
Dev=numpy.std(d)
print(Dev)
# Out:
# 1.3977827441475434

# %% [markdown]
# ![image.png](attachment:316aab4f-bc7c-4789-8bfd-710ed8999e79.png)
