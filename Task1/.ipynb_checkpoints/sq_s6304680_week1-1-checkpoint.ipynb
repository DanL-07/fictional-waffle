# %% [markdown]
# * Name: Daniel Alvarez
# * Username: dalvarez
# * Student s-number: S6304680
# * Group (AS1, etc.): As2

# %%
22/7
# Out:
# 3.142857142857143

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi=22/7 # Proccesed on JptHub

# %% [markdown]
# ![image.png](attachment:2957d343-c13f-441d-91b0-678d82d5c45e.png)

# %%
6*5*4*3*2*1
# Out:
# 720

# %%
import math

# %%
from scipy.constants import h

# %%
freq=2.42*10**28

# %%
E=h*freq

# %%
E
# Out:
# 1.6035089762999996e-05

# %%
from scipy.constants import G

# %%
Mmoon=7.342*10**22

# %%
Mearth=5.9722*10**24

# %%
d=385000000.6

# %%
F=G*Mmoon*Mearth/d**2

# %%
F
# Out:
# 1.9743901995827397e+20

# %%
from scipy.constants import pi
